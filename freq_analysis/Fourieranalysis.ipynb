# %%
import numpy as np
import matplotlib.pyplot as plt
from math import sin
from scipy.fft import fft, fftfreq
# Number of sample points

# %%
N = 600
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N, endpoint=False)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = fft(y)
xf = fftfreq(N, T)[:N//2]

plt.figure()
plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.show()

plt.figure()
plt.plot(x, y)
plt.grid()
plt.show()

# %%
z = np.zeros(100)
t = np.arange(0,2,0.01)
# f = lambda t: sin(t)*np.exp(0.1*t)
# f = np.exp(-0.05*t) * np.sin(0.1*t)
freq = 1
w = 2*np.pi*freq
f = np.sin(w*t)
print(type(f))
# npfunc = np.frompyfunc(f, 1, 1)
# wave = npfunc(t)
fourier = np.abs(np.fft.fft(f))
freq = np.fft.fftfreq(t.shape[-1], d = 0.01)
print(type(amp))

# # ignal = np.array([-2, 8, 6, 4, 1, 0, 3, 5], dtype=float)
# fourier = np.fft.fft(signal)
# n = signal.size
# timestep = 0.1
# freq = np.fft.fftfreq(n, d=timestep)
# freq
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
z = np.zeros(100)
t = np.arange(0,2,0.01)
# f = lambda t: sin(t)*np.exp(0.1*t)
# f = np.exp(-0.05*t) * np.sin(0.1*t)
freq = 1
w = 2*np.pi*freq
f = np.sin(w*t)
print(type(f))
# npfunc = np.frompyfunc(f, 1, 1)
# wave = npfunc(t)
fourier = np.fft.rfft(f)
freq = np.fft.rfftfreq(t.shape[-1], d = 0.01)

print(type(amp))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
# plt.plot(t,f)
plt.figure()
plt.plot(t,f)

plt.figure()
plt.plot(t, amp)
