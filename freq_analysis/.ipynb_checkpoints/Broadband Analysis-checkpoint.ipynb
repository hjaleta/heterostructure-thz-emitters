# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
E = np.loadtxt("../testsave copy.out")
E = E[:,0].flatten()
t = np.arange(1000)
fig, ax = plt.subplots()
ax.plot(t[100:], np.abs(E[100:]))
ax.set_yscale("log")
plt.plot(82,0, "*")
print(E[-1])
# Out:
# -120.20331442186917

# %%
E_t = np.gradient(E)
plt.figure()
plt.plot(t, E_t, "--")
plt.figure()
plt.plot(t,E)

# %%
action = False
last = None
first = None

E_lim = np.amax(np.abs(E))/100
E_t_lim = np.amax(np.abs(E_t))/100

max_lim = None
min_lim = None

for i, (E_i, E_t_i) in enumerate(zip(E, E_t)):
    
    if abs(E_i) > E_lim/10 and not action:
        min_lim = i
        action = True
    if action and i > min_lim + 100:
        if (abs(E_i) < E_lim) and (abs(E_t_i) < E_t_lim):
            max_lim = i
            break

plt.plot(t, E)
plt.plot(min_lim, E[min_lim], "*")
plt.plot(max_lim, E[max_lim], "*")

# %%
E_trunc = E[min_lim:max_lim]
t_trunc = t[min_lim:max_lim]
E_fourier = np.abs(np.fft.rfft(E_trunc))
freq = np.fft.rfftfreq(E_trunc.shape[0], d = 1)*1000
print(freq.shape)
# for i, (amp, f) in enumerate(zip(E_fourier, freq)):
# Out:
# (151,)

# %%
fig, (ax1, ax2) = plt.subplots(2,1, figsize = (8,6))
print(ax)

ax1.plot(t_trunc, E_trunc)
ax1.set_ylabel(r"E(t)", rotation = "horizontal", size = "x-large")
ax1.set_xlabel("Time [fs]", size = "x-large")
ax2.plot(freq, E_fourier)
ax2.set_ylabel(r"|E(t)|", rotation = "horizontal", size = "xx-large", labelpad = 30)
ax2.set_xlabel("Frequency [THz]", size = "x-large")
ax2.set_yscale('log')
ax2.set_xscale('log')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
# Out:
# [<AxesSubplot:> <AxesSubplot:>]
